# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Machine Learning & Deep Learning</b></center>
#
# <center><b><h1>Lab - 5</b></center>
#     <center><b><h1>Mansi Fatepara</b></center>
#     <center><b><h1>23/12/2025</b></center>
# <pre>

# %% [markdown]
# # SVR

# %% [markdown]
# # Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Read World bank CSV

# %%
df = pd.read_csv('WorldBank.csv')

# %%
df
# Out:
#      Country Name Country Code  \
# 0           India          IND
# 1           India          IND
# 2           India          IND
# 3           India          IND
# 4           India          IND
# ...           ...          ...
# 1435        India          IND
# 1436        India          IND
# 1437        India          IND
# 1438        India          IND
# 1439        India          IND
#
#                                          Indicator Name        Indicator Code  \
# 0                       Export value index (2000 = 100)     TX.VAL.MRCH.XD.WD
# 1     Insurance and financial services (% of commerc...     TX.VAL.INSF.ZS.WT
# 2     Merchandise imports by the reporting economy, ...     TM.VAL.MRCH.RS.ZS
# 3               Food imports (% of merchandise imports)     TM.VAL.FOOD.ZS.UN
# 4     Share of tariff lines with international peaks...     TM.TAX.MRCH.IP.ZS
# ...                                                 ...                   ...
# ...

# %% [markdown]
# # Perform conditional selection to find - Population ages 15-64 (% of total population)

# %%
data = df[df['Indicator Name'] == 'Population ages 15-64 (% of total population)']
data
# Out:
#   Country Name Country Code                                 Indicator Name  \
# 9        India          IND  Population ages 15-64 (% of total population)
#
#       Indicator Code      1960       1961       1962       1963       1964  \
# 9  SP.POP.1564.TO.ZS  56.49748  56.177532  55.807455  55.461664  55.248939
#
#         1965  ...       2011       2012       2013      2014       2015  \
# 9  55.211351  ...  64.429404  64.805519  65.208489  65.59598  65.944164
#
#         2016       2017       2018       2019  2020
# 9  66.274262  66.538187  66.766743  67.003811   NaN
#
# [1 rows x 65 columns]

# %% [markdown]
# # Divide the data into input and output

# %%
x = np.arange(1960,2020).reshape(-1,1)

# %%
x
# Out:
# array([[1960],
#        [1961],
#        [1962],
#        [1963],
#        [1964],
#        [1965],
#        [1966],
#        [1967],
#        [1968],
#        [1969],
#        [1970],
#        [1971],
#        [1972],
#        [1973],
#        [1974],
#        [1975],
#        [1976],
#        [1977],
#        [1978],
#        [1979],
#        [1980],
#        [1981],
#        [1982],
#        [1983],
#        [1984],
#        [1985],
#        [1986],
#        [1987],
#        [1988],
#        [1989],
#        [1990],
#        [1991],
#        [1992],
#        [1993],
#        [1994],
#        [1995],
#        [1996],
#        [1997],
#        [1998],
#        [1999],
#        [2000],
#        [2001],
#        [2002],
#        [2003],
#        [2004],
#        [2005],
#        [2006],
#        [2007],
#        [2008],
#        [2009],
#        [2010],
#        [2011],
#        [2012],
#        [2013],
#        [2014],
#        [2015],
#        [2016],
#        [2017],
# ...

# %%
y = data.values[0][4:-1].reshape(-1,1)

# %%
y
# Out:
# array([[56.49748004],
#        [56.17753236],
#        [55.80745463],
#        [55.46166361],
#        [55.24893881],
#        [55.21135053],
#        [55.09090078],
#        [55.15534672],
#        [55.34507283],
#        [55.57014408],
#        [55.78194745],
#        [55.85676846],
#        [55.95268174],
#        [56.07247186],
#        [56.23447551],
#        [56.44405309],
#        [56.49722595],
#        [56.62068516],
#        [56.78900152],
#        [56.9691436],
#        [57.1425581],
#        [57.18105454],
#        [57.22630775],
#        [57.28875038],
#        [57.39054366],
#        [57.54142108],
#        [57.55350984],
#        [57.6545119],
#        [57.81875323],
#        [58.01501187],
#        [58.22990246],
#        [58.37403848],
#        [58.5472698],
#        [58.75605047],
#        [59.012126],
#        [59.31657719],
#        [59.56507329],
#        [59.8572303],
#        [60.18600058],
#        [60.53971518],
#        [60.90862046],
# ...

# %% [markdown]
# # Plot scatter plot of Population ages 15-64 (% of total population)

# %%
plt.scatter(x,y)

# %% [markdown]
# # Feature Scaling (Mandatory for SVR)**
# SVR is highly sensitive to the range of data points. If we don't scale (normalize) the data, the model will fail to find the correct hyperplane.

# %%
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler

# %%
sc_x = StandardScaler()
sc_y = StandardScaler()

x_scaled = sc_x.fit_transform(x)
y_scaled = sc_y.fit_transform(y)

print("Scaling Complete")
# Out:
# Scaling Complete

# %% [markdown]
# # Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x_scaled,y_scaled,test_size=0.3,random_state=0)

# %% [markdown]
# # Fitting SVR on 3 Different Kernel on dataset

# %%
from sklearn.svm import SVR

# %%
model_rbf = SVR()

# %%
model_rbf.fit(x_train,y_train.ravel())
#ravel is used for convert from two dimension into one dimension(for y only)
# Out:
# SVR()

# %%
#initialize models
svr_lin = SVR(kernel='linear')
svr_poly = SVR(kernel='poly',degree=3)
svr_rbf = SVR(kernel='rbf')# default SVR() is take the rbf kernel

# fit models
svr_lin.fit(x_scaled,y_scaled.ravel())
svr_poly.fit(x_scaled,y_scaled.ravel())
svr_rbf.fit(x_scaled,y_scaled.ravel())
# Out:
# SVR()

# %%
# convert a smooth range of x values for plotting curve

x_grid = np.arange(min(x_test),max(x_test),1)
x_grid = x_grid.reshape(len(x_grid),1)

plt.scatter(x,y,color='red',label='real data')

plt.plot(sc_x.inverse_transform(x_grid),sc_y.inverse_transform(model_rbf.predict(x_grid).reshape(-1,1)),color='blue',label='SVR (RBF)')

plt.title('SVR Regression Model')
plt.xlabel('Year / Features')
plt.ylabel('population / Target')
plt.legend()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15352\840643672.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_grid = np.arange(min(x_test),max(x_test),1)

# %% [markdown]
# # Predict the x_test using 3 kernel

# %%
model_rbf.score(x_train,y_train)
# Out:
# 0.9947138713539011

# %%
model_rbf.score(x_test,y_test)
# Out:
# 0.9880623181593732

# %%
# Out:
# array([57.55350984, 59.31657719, 67.00381119, 57.81875323, 55.85676846,
#        55.80745463, 59.012126, 66.7667425, 60.90862046, 57.22630775,
#        55.24893881, 55.78194745, 58.22990246, 61.18898716, 58.75605047,
#        61.83084479, 63.74196691, 55.15534672], dtype=object)

# %%
# Out:
# array([57.73445326, 59.30206118, 64.8451716 , 57.99812952, 55.96479236,
#        56.12587167, 59.06485884, 64.91876466, 60.76906052, 57.24445561,
#        55.93360816, 55.89821768, 58.29641078, 61.1088798 , 58.84682535,
#        61.81299688, 63.81278461, 55.81527994])

# %% [markdown]
# # Visualising the  results

# %%
#initialize models
svr_lin = SVR(kernel='linear')
svr_poly = SVR(kernel='poly',degree=3)
svr_rbf = SVR(kernel='rbf')# default SVR() is take the rbf kernel

# fit models
svr_lin.fit(x_scaled,y_scaled.ravel())
svr_poly.fit(x_scaled,y_scaled.ravel())
svr_rbf.fit(x_scaled,y_scaled.ravel())

#visualization code here

plt.figure(figsize=(12,8))
plt.scatter(x,y,color='green',label='data')

# plot lines
plt.plot(sc_x.inverse_transform(x_grid),sc_y.inverse_transform(svr_lin.predict(x_grid).reshape(-1,1)),color='skyblue',label='Linear')
plt.plot(sc_x.inverse_transform(x_grid),sc_y.inverse_transform(svr_poly.predict(x_grid).reshape(-1,1)),color='pink',label='Polynomial')
plt.plot(sc_x.inverse_transform(x_grid),sc_y.inverse_transform(svr_rbf.predict(x_grid).reshape(-1,1)),color='yellow',label='SVR (RBF)')

plt.xlabel('data')
plt.ylabel('target')
plt.title('Support Vector Regression Kernel Comparision')
plt.legend()
plt.show()

# %% [markdown]
# ### **Student Activity : Prediction**
# **Task:** Predict the value for the Year **2025** (or value 6.5 in the demo data).
# Remember: You must transform the input before predicting, and inverse transform the output.

# %%
# Example: Predicting for a new value
value_to_predict = [[2025]] # replace with [[2025]] for real data

# 1.scale input
val_scaled = sc_x.transform(value_to_predict)

# 2.predict value for linear
pred_scaled = svr_lin.predict(val_scaled) # here pred_scaled is the scaled output

# 3.inverse transform output
pred_final = sc_y.inverse_transform(pred_scaled.reshape(-1,1))

print(f"The predicted value for input {value_to_predict[0][0]} is : {pred_final[0][0]:.2f}")
# Out:
# The predicted value for input 2025 is : 66.47
